# %%
import pandas as pd
from fbprophet import Prophet

# %%
df = pd.read_csv('data.csv')

# %%
df.head()
# Out:
#          Date   Open   High    Low  Close  Adj Close        Volume
# 0  2000-01-03  5.875  5.875  5.875  5.875   3.598474  3.538944e+10
# 1  2000-01-04  5.550  5.550  5.550  5.550   3.399410  2.886144e+10
# 2  2000-01-05  5.494  5.494  5.494  5.494   3.365107  4.303360e+10
# 3  2000-01-06  5.475  5.475  5.475  5.475   3.353470  3.405568e+10
# 4  2000-01-07  5.500  5.500  5.500  5.500   3.368784  2.091264e+10

# %%
df['Date'] = pd.to_datetime(df['Date']).dt.date

# %%
df.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume       float64
# dtype: object

# %%
df = df[['Date','Close']]
df.columns = ['ds','y']

# %%
df.head()
# Out:
#            ds      y
# 0  2000-01-03  5.875
# 1  2000-01-04  5.550
# 2  2000-01-05  5.494
# 3  2000-01-06  5.475
# 4  2000-01-07  5.500

# %%
m = Prophet()
m.fit(df)
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
future = m.make_future_dataframe(periods=365)
future.tail()
# Out:
#              ds
# 5849 2022-10-28
# 5850 2022-10-29
# 5851 2022-10-30
# 5852 2022-10-31
# 5853 2022-11-01

# %%
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#              ds       yhat  yhat_lower  yhat_upper
# 5849 2022-10-28  31.198573   26.088119   36.512076
# 5850 2022-10-29  31.065802   25.904290   36.574092
# 5851 2022-10-30  31.081774   25.710620   36.324024
# 5852 2022-10-31  31.258662   26.042054   36.809850
# 5853 2022-11-01  31.269464   25.780504   36.304358

# %%
fig1 = m.plot(forecast)

# %%
m.plot_components(forecast)

# %%
future = m.make_future_dataframe(periods=365)
future['cap'] = 5
fcst = m.predict(future)
fig = m.plot(fcst)

# %%
df['y'] = 10 - df['y']
df['cap'] = 6
df['floor'] = 0
future['cap'] = 6
future['floor'] = 0
m = Prophet(growth='logistic')
m.fit(df)
fcst = m.predict(future)
fig = m.plot(fcst)
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
from prophet.diagnostics import cross_validation
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-80-fe103812e3b7> in <module>
# ----> 1 from prophet.diagnostics import cross_validation
#
# ModuleNotFoundError: No module named 'prophet'
